# %%
# %pip install --upgrade vllm -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.4/326.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 95.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 107.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.4/862.4 kB 61.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 MB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.7/913.7 kB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 103.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 28.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-instrumentation-asgi 0.53b1 requires opentelemetry-semantic-conventions==0.53b1, but you have opentelemetry-semantic-conventions 0.47b0 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.53b1 requires opentelemetry-semantic-conventions==0.53b1, but you have opentelemetry-semantic-conventions 0.47b0 which is incompatible.
# opentelemetry-instrumentation 0.53b1 requires opentelemetry-semantic-conventions==0.53b1, but you have opentelemetry-semantic-conventions 0.47b0 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# google-cloud-pubsub 2.29.0 requires opentelemetry-api>=1.27.0; python_version >= "3.8", but you have opentelemetry-api 1.26.0 which is incompatible.
# google-cloud-pubsub 2.29.0 requires opentelemetry-sdk>=1.27.0; python_version >= "3.8", but you have opentelemetry-sdk 1.26.0 which is incompatible.
# cudf-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# dask-cuda 25.2.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# distributed-ucxx-cu12 0.42.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# cuml-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.

# %%
# %pip install --upgrade langchain langchain-community langchain-core langchain-huggingface langchain-chroma langchain-text-splitters pypdf sentence-transformers chromadb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 78.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 86.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 98.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %% [markdown]
# # RAG: Retrieval Augmented Generation
#
# <a target="_blank" href="https://colab.research.google.com/github/juanhuguet/intro_to_llms/blob/main/intro_to_llms/03_local_rag_qa.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# ![](https://python.langchain.com/assets/images/rag_indexing-8160f90a90a33253d0154659cf7d453f.png)

# %% [markdown]
# ![](https://python.langchain.com/assets/images/rag_retrieval_generation-1046a4668d6bb08786ef73c56d4f228a.png)

# %% [markdown]
# # Importamos las funcionalidades de langchain

# %%
from langchain.chains import create_retrieval_chain

# %%
from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
from langchain_community.llms.vllm import VLLM

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from langchain_chroma import Chroma

# %%
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# Seteamos las variables de entorno con la api key de openAI

# %% [markdown]
# ## Preprocesamos el pdf
#
# PyPDF loader se encarga automáticamente de leer y extraer el texto.
#
# El splitter, crea `chunks` a partir del texto de aprox. 1000 caracteres y un overlap de 200 para no perder info.

# %%
loader = PyPDFLoader("sample_data/insurance_policy_example.pdf")

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

chunks = loader.load_and_split(text_splitter=text_splitter)

# %% [markdown]
# ### Cargamos el documento en la base de datos vectorial.
#
# Usamos chroma, que esta en memoría y no requiere setup, y los embeddings a partir de OpenAI.

# %%
embedder = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# populamos la base de datos con los chunks, y los embedings
docsearch = Chroma.from_documents(chunks, embedder)

# %% [markdown]
# ### Creamos el `retriever`.
#
# Esta pieza permite dada una query, calcular su embedding y recuperar los  k chunks más relevantes para formar el contexto

# %%
retriever=docsearch.as_retriever(search_type="mmr", fetch_k=10, k=3, return_source_documents=True)

# %% [markdown]
# ### Creamos el reader
#
# Una vez recuperamos el contexto, lo pasaremos a un llm. Usaremos gpt-3.5-turbo, que tiene un buen ratio performance/coste

# %%
reader = VLLM(
    model="TheBloke/Mistral-7B-Instruct-v0.2-AWQ",
    trust_remote_code=True,  # mandatory for hf models
    max_new_tokens=1000,
    top_p=0.95,
    stop=["\n\n"],
    temperature=0.3,
    vllm_kwargs={"quantization": "awq",
                 "max_model_len": 10000},
)
# Out:
# INFO 04-30 15:38:03 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 04-30 15:38:03 [__init__.py:239] Automatically detected platform cuda.
# config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# INFO 04-30 15:38:24 [config.py:717] This model supports multiple tasks: {'classify', 'score', 'generate', 'embed', 'reward'}. Defaulting to 'generate'.
# WARNING 04-30 15:38:26 [config.py:830] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# WARNING 04-30 15:38:26 [arg_utils.py:1658] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# INFO 04-30 15:38:26 [llm_engine.py:240] Initializing a V0 LLM engine (v0.8.5) with config: model='TheBloke/Mistral-7B-Instruct-v0.2-AWQ', speculative_config=None, tokenizer='TheBloke/Mistral-7B-Instruct-v0.2-AWQ', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=10000, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=awq, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=None, served_model_name=TheBloke/Mistral-7B-Instruct-v0.2-AWQ, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=None, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# INFO 04-30 15:38:29 [cuda.py:240] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 04-30 15:38:29 [cuda.py:289] Using XFormers backend.
# INFO 04-30 15:38:31 [parallel_state.py:1004] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 04-30 15:38:31 [model_runner.py:1108] Starting to load model TheBloke/Mistral-7B-Instruct-v0.2-AWQ...
# INFO 04-30 15:38:32 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/4.15G [00:00<?, ?B/s]
# INFO 04-30 15:39:01 [weight_utils.py:281] Time spent downloading weights for TheBloke/Mistral-7B-Instruct-v0.2-AWQ: 29.234681 seconds
# INFO 04-30 15:39:01 [weight_utils.py:315] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 04-30 15:39:03 [loader.py:458] Loading weights took 1.78 seconds
# INFO 04-30 15:39:03 [model_runner.py:1140] Model loading took 3.8811 GiB and 32.213882 seconds
# INFO 04-30 15:39:10 [worker.py:287] Memory profiling takes 5.96 seconds
# INFO 04-30 15:39:10 [worker.py:287] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.90) = 13.27GiB
# INFO 04-30 15:39:10 [worker.py:287] model weights take 3.88GiB; non_torch_memory takes 0.02GiB; PyTorch activation peak memory takes 1.03GiB; the rest of the memory reserved for KV Cache is 8.33GiB.
# INFO 04-30 15:39:10 [executor_base.py:112] # cuda blocks: 4266, # CPU blocks: 2048
# INFO 04-30 15:39:10 [executor_base.py:117] Maximum concurrency for 10000 tokens per request: 6.83x
# INFO 04-30 15:39:15 [model_runner.py:1450] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/35 [00:00<?, ?it/s]
# INFO 04-30 15:40:14 [model_runner.py:1592] Graph capturing finished in 58 secs, took 0.48 GiB
# INFO 04-30 15:40:14 [llm_engine.py:437] init engine (profile, create kv cache, warmup model) took 70.48 seconds

# %% [markdown]
# ## Creamos el prompt
#
# Para poder controlar el comportamiento del modelo, creamos un prompt para dar instrucciones

# %%
prompt_template = \
"""Use the following pieces of context to answer the question at the end.
If you don't know the answer, don't try to make up an answer and answer `not-in-text`
Answer in english only.

Context:

{context}

Question:

{input}

Answer:"""

PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "input"])

# %% [markdown]
# ## Creamos la cadena de QA
#
# Usamos el wrapper de langchain que se ocupa de orquestar el flujo de dato:
#
# `query` -> `embedding` -> `retrieve context` -> `prompt completion` -> answer

# %%
from langchain.chains.retrieval import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import PromptTemplate

# Assuming you have already defined:
# - reader: your LLM instance (e.g., VLLM)
# - retriever: your retriever instance (e.g., from Chroma)
# - PROMPT: your PromptTemplate instance

# Step 1: Create the document combination chain
combine_docs_chain = create_stuff_documents_chain(llm=reader, prompt=PROMPT)

# Step 2: Create the retrieval chain
qa = create_retrieval_chain(retriever=retriever, combine_docs_chain=combine_docs_chain)

# Step 3: Invoke the chain with your query
response = qa.invoke({"input": "What is the Title?"})

# Access the answer and source documents
answer = response["answer"]
source_documents = response.get("context", [])
# Out:
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
answer
# Out:
# '\n\nThe title of the document is "Premier Plus Homeowners Policy"'

# %% [markdown]
# ## Prueba del sistema

# %% [markdown]
# Vamos a ver como responde a la siguiente pregunta:
#
# What are the issues that are not covered by the insurance ?

# %%
results = qa.invoke({"input": "What is the parent company?"})
# Out:
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
print(results["answer"])
# Out:
# The parent company of Auto Club Family Insurance Company is The Automobile Club Inter-Insurance Exchange.

# %%
print(len(results["context"]))

for doc in results["context"]:
  print(doc.model_dump_json(indent=2))
# Out:
# 4
# {
#   "id": "f03e4494-7abe-4e0b-9391-8761316d11c6",
#   "metadata": {
#     "author": "N402153",
#     "creationdate": "2013-06-27T10:20:31-05:00",
#     "creator": "PScript5.dll Version 5.2.2",
#     "moddate": "2013-07-01T14:39:01-05:00",
#     "page": 0,
#     "page_label": "1",
#     "producer": "Acrobat Distiller 7.0.5 (Windows)",
#     "source": "sample_data/insurance_policy_example.pdf",
#     "title": "Microsoft Word - 5105 072011.doc",
#     "total_pages": 78
#   },
#   "page_content": "SAMPLE DOCUMENT\n  \n \n \n \n  \n \n  \n \n  \n \nPREMIER PLUS \nHOMEOWNERS \nPOLICY \n \n  \n \n  \nAuto Club Family Insurance Company \n12901 North Forty Drive  St. Louis, Missouri 63141 \n(314) 523-7350  \n \n \n \nA STOCK COMPANY \n \nA SUBSIDIARY OF THE AUTOMOBILE \nCLUB INTER-INSURANCE EXCHANGE",
#   "type": "Document"
# }
# {
#   "id": "602845b9-3be2-43c5-b30e-3febb6b26f15",
#   "metadata": {
#     "author": "N402153",
#     "creationdate": "2013-06-27T10:20:31-05:00",
#     "creator": "PScript5.dll Version 5.2.2",
#     "moddate": "2013-07-01T14:39:01-05:00",
#     "page": 64,
#     "page_label": "65",
#     "producer": "Acrobat Distiller 7.0.5 (Windows)",
#     "source": "sample_data/insurance_policy_example.pdf",
#     "title": "Microsoft Word - 5105 072011.doc",
#     "total_pages": 78
#   },
#   "page_content": "SAMPLE DOCUMENT\n61 \n  (3) supervision of any person in the \nmaintenance, use, loading or \nunloading;  \n  of motorized vehicles, including trailers of \nany type, watercraft or aircraft. \n h. Arising out of the ownership of, custody of, \nor the care for a pure or mixed breed \nAmerican pit bull terrier (also known as an \nAmerican Staffordshire terrier, pit bull \nterrier or pit bull), Rottweiler or Canary (also known as a Presa Canario or a Perro \nde Presa Canario) dog. \n 4. LOSS ASSESSMENT \n We will pay up to $1,000 for your share of loss \nassessment charged during the policy period \nagainst you by a corporation or association of \nproperty owners, when the assessment is \nmade as a result of: \n a. bodily injury  or property damage  not \nexcluded under SECTION II of this policy; or \n b. liability for an act of a director, officer or \ntrustee in the capacity as a director, officer or trustee, provided: \n  (1) the director, officer or trustee is elected",
#   "type": "Document"
# }
# {
#   "id": "279e405a-afd2-4071-8132-c94162a8dc60",
#   "metadata": {
#     "author": "N402153",
#     "creationdate": "2013-06-27T10:20:31-05:00",
#     "creator": "PScript5.dll Version 5.2.2",
#     "moddate": "2013-07-01T14:39:01-05:00",
#     "page": 56,
#     "page_label": "57",
#     "producer": "Acrobat Distiller 7.0.5 (Windows)",
#     "source": "sample_data/insurance_policy_example.pdf",
#     "title": "Microsoft Word - 5105 072011.doc",
#     "total_pages": 78
#   },
#   "page_content": "carried on motorized vehicles; \n  (2) motorized vehicles: \n   (a) designed to assist and used by the \nphysically handicapped if: \n    (i) not subject to motorized \nvehicle registration; and \n    (ii) not designed, constructed or \naltered for travel on public roads; \n   (b) stored on an insured location and \ninoperable; \n   (c) used exclusively on an insured \nlocation; \n   (d) designed for recreational use off \npublic roads, not subject to \nmotorized vehicle registration  \nand not owned by any insured; \n   (e) motorized golf carts not licensed \nand not required to be licensed for highway use; or \n    (f) off an insured location  and the  \n  motorized vehicle is: \n    (i) designed as a toy vehicle for \nuse by children under thirteen \nyears of age;",
#   "type": "Document"
# }
# {
#   "id": "0a9496f5-8336-45ad-8e19-2ce09060b95c",
#   "metadata": {
#     "author": "N402153",
#     "creationdate": "2013-06-27T10:20:31-05:00",
#     "creator": "PScript5.dll Version 5.2.2",
#     "moddate": "2013-07-01T14:39:01-05:00",
#     "page": 59,
#     "page_label": "60",
#     "producer": "Acrobat Distiller 7.0.5 (Windows)",
#     "source": "sample_data/insurance_policy_example.pdf",
#     "title": "Microsoft Word - 5105 072011.doc",
#     "total_pages": 78
#   },
#   "page_content": "SAMPLE DOCUMENT\n56 \n q. Bodily injury or property damage \nconsisting of, arisi ng out of, caused by, \ncontributed to, aggravated by or resulting \nfrom, whether directly or indirectly, by fungi, wet or dry rot, or bacteria. \n  This includes:   (1) the cost of remediation, testing, \nmonitoring, abating, mitigating, \nremoving or disposing of fungi, wet or \ndry rot, or bacteria; \n  (2) any supervision, instruction, \ndisclosures, or failures to disclose, \nrecommendations, warnings, or advice \ngiven, or that allegedly should have \nbeen given, in connection with bodily \ninjury or property damage consisting \nof, arising out of, caused by, contributed to, aggravated by or resulting from, whether directly or \nindirectly, by fungi, wet or dry rot, or \nbacteria, of the activities described in \n(1) above; \n  (3) any obligation to share damages, \nlosses, costs, pay ments or expenses \nwith or repay someone else who must \nmake payment because of such bodily \ninjury or property damage, damages,",
#   "type": "Document"
# }
